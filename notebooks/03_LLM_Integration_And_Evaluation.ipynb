# %%
# !pip install google-genai

# %%
# !git clone https://github.com/FlagOpen/FlagEmbedding.git
# %cd FlagEmbedding
# !pip install -e .
# Out:
# Cloning into 'FlagEmbedding'...
# remote: Enumerating objects: 11544, done.
# remote: Counting objects: 100% (3549/3549), done.
# remote: Compressing objects: 100% (1262/1262), done.
# remote: Total 11544 (delta 2338), reused 2287 (delta 2287), pack-reused 7995 (from 1)
# Receiving objects: 100% (11544/11544), 51.36 MiB | 26.37 MiB/s, done.
# Resolving deltas: 100% (6593/6593), done.
# /kaggle/working/FlagEmbedding
# Obtaining file:///kaggle/working/FlagEmbedding
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 947.8/947.8 kB 4.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 21.8 MB/s eta 0:00:00a 0:00:01
# ...
#   Running setup.py develop for FlagEmbedding
# ...

# %%
import os
os.environ["GEMINI_API_KEY"] = "YOUR_API_KEY" # Enter your Gemini API key here

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("madhavkumar244/madhavscuadhn")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/datasets/madhavkumar244/madhavscuadhn

# %%
# !python /kaggle/input/datasets/madhavkumar244/madhavscuadhn/evaluate_llm.py
# Out:
# ...
# LLM / RAG EVALUATION
# ...
# Contracts available : 102
# Questions to test   : 1244
#
# Starting fresh evaluation.
#
# Loading RAG system...
# Loading retriever...
# ...
# Loading weights: 100%|█| 199/199 [00:00<00:00, 1058.32it/s, Materializing param=
# ✓ Retriever loaded
# Loading reranker...
# Loading weights: 100%|█| 201/201 [00:00<00:00, 1479.48it/s, Materializing param=
# ✓ Reranker loaded
# ✓ Gemini client loaded
#
# ✓ RAG system ready
#
#
# ...
# QUESTION 1/1244
# ...
# Highlight the parts (if any) of this contract related to "Document Name" that should be reviewed by a lawyer. Details: The name of the contract
#
# ----------------------------------------------------------------------
# LLM ANSWER
# ----------------------------------------------------------------------
# Based on the provided contract excerpts, the part related to the "Document Name" (the name of the contract) that should be reviewed by a lawyer is:
#
# * **"SUPPLY CONTRACT"** (from Excerpt 1)
#
# ...

# %%
# !python /kaggle/input/datasets/madhavkumar244/madhavscuadhn/evaluate_llm_metrics.py
# Out:
# ...
# LLM / RAG ANSWER-LEVEL EVALUATION
# ...
#
# Checking files...
# Contract index : /kaggle/input/datasets/madhavkumar244/madhavscuadhn/test_contract_index.json
# LLM results    : /kaggle/working/llm_evaluation_results.jsonl
#
# Loading CUAD test index...
# Contracts loaded : 102
# Ground-truth questions : 4182
# Questions with evidence : 1244
#
# Loading Gemini evaluation results...
# LLM results loaded : 1244
#
# Loading semantic evaluation model...
# ...
# config.json: 100%|█████████████████████████████| 759/759 [00:00<00:00, 2.34MB/s]
# tokenizer_config.json: 1.29kB [00:00, 771kB/s]
# vocab.txt: 232kB [00:00, 5.19MB/s]
# tokenizer.json: 711kB [00:00, 62.1MB/s]
# special_tokens_map.json: 100%|█████████████████| 695/695 [00:00<00:00, 4.76MB/s]
# model.safetensors: 100%|█████████████████████| 438M/438M [00:18<00:00, 24.0MB/s]
# Loading weights: 100%|█| 199/199 [00:00<00:00, 1015.96it/s, Materializing param=
# ✓ Semantic model loaded
# Processed 100/1244
# Processed 300/1244
# Processed 500/1244
# ...
